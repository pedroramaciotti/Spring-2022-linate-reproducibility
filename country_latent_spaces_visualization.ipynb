# %%
# global definitions

import pandas as pd

import seaborn as sn

import matplotlib.pyplot as plt

import numpy as np

# ChileOwn
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/chile_own/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/chile_own/exp_results/target_ideological_dimensions.csv'
#country = 'Chile'

# France
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/france/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/france/exp_results/target_ideological_dimensions.csv'
#country = 'France'

# FranceOwn
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/france_own/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/france_own/exp_results/target_ideological_dimensions.csv'
#country = 'France'

# Germany
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/germany/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/germany/exp_results/target_ideological_dimensions.csv'
#country = 'Germany'

# GermanyOwn
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/germany_own/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/germany_own/exp_results/target_ideological_dimensions.csv'
#country = 'Germany'

# Italy
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/italy/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/italy/exp_results/target_ideological_dimensions.csv'
#country = 'Italy'

# ItalyOwn
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/italy_own/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/italy_own/exp_results/target_ideological_dimensions.csv'
#country = 'Italy'

# UK
#followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/uk/exp_results/source_ideological_dimensions.csv'
#parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/uk/exp_results/target_ideological_dimensions.csv'
#country = 'UK'

# UKOwn
followers_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/uk_own/exp_results/source_ideological_dimensions.csv'
parliamentarians_latent_dimensions_file = '/home/foula/linate/plos_asonam_exp_data/uk_own/exp_results/target_ideological_dimensions.csv'
country = 'UK'

# %%
# load latent dimensions

followers_df = pd.read_csv(followers_latent_dimensions_file)
followers_df.rename({'source_id': 'id'}, axis = 1, inplace = True)
followers_df['id'] = followers_df.apply (lambda row: 'f_' + str(int(row['id'])), axis = 1)
followers_df.head()

parliamentarians_df = pd.read_csv(parliamentarians_latent_dimensions_file)
parliamentarians_df.rename({'target_id': 'id'}, axis = 1, inplace = True)
parliamentarians_df['id'] = parliamentarians_df.apply (lambda row: 'p_' + str(int(row['id'])), axis = 1)
parliamentarians_df.head()
# Out:
#     id  latent_dimension_0  latent_dimension_1  latent_dimension_2  \
# 0  p_0           -0.049909           -0.356612           -0.569107
# 1  p_1           -0.059989           -0.326236           -0.252614
# 2  p_2           -0.248030            0.335281            1.190521
# 3  p_3           -0.228362            0.413195            1.323919
# 4  p_4           -0.211694            0.341597            1.174134
#
#    latent_dimension_3  latent_dimension_4  latent_dimension_5  \
# 0            0.256374           -0.420723           -0.443170
# 1            1.195728           -0.365517            0.749878
# 2            0.588142           -0.169941           -0.591205
# 3            0.792808           -0.020815           -0.339281
# 4            0.699659           -0.384474           -0.468222
#
#    latent_dimension_6  latent_dimension_7  latent_dimension_8  ...  \
# 0           -0.016806           -0.061831            0.375665  ...
# ...

# %%
# visualization of two dimensions

xdim = 'latent_dimension_0'
ydim = 'latent_dimension_1'

ren = {xdim: 'x', ydim: 'y'}

f_df = followers_df.rename(columns = ren).drop_duplicates(subset = ['x', 'y'])
p_df = parliamentarians_df.rename(columns = ren).drop_duplicates(subset = ['x', 'y'])
df = pd.concat([f_df, p_df], axis = 0)
df = df[~df.index.duplicated()]

# use the followers + parliamentarians
g = sn.jointplot(x = 'x', y = 'y', data = df, space = 0, color = "deepskyblue", 
                 kind = 'hex', ratio = 10, height = 5, xlim = (-3, 2), ylim = (-3, 2))
g.ax_joint.set_xlabel(r'$\delta_1$')
g.ax_joint.set_ylabel(r'$\delta_2$')

#cbar_ax = g.fig.add_axes()  
#cbar_ax = g.fig.add_axes([0.15, .2, .025, .3]) #
#plt.colorbar(cax = cbar_ax)
#for idx,row in df_nuclear.iterrows():
#    g.ax_joint.plot(row[xdim],row[ydim],'+',color='red',mew=1.0,ms=7)
#for idx,row in Parties_df.iterrows():
#    g.ax_joint.plot(Parties_df[Parties_df['party']==row['party']][xdim].values,Parties_df[Parties_df['party']==row['party']][ydim].values,'o',color='k',mew=1.5,ms=7,mec='k')
#    txt = g.ax_joint.text(row[xdim]+disp[row['party']][0],row[ydim]+disp[row['party']][1],row.party,color='white',bbox=dict(boxstyle="round",ec='black',fc='k',alpha=1,),fontsize=9)
#g.ax_joint.plot([0,10,10,0,0],[0,0,10,10,0],color='w',linestyle='-',alpha=1)
#g.ax_joint.plot([0,10,10,0,0],[0,0,10,10,0],color='k',linestyle='--',alpha=1)
# g.ax_joint.legend(handles=custom_legend,loc='lower right',fontsize=10)
#txt = g.ax_joint.text(2,10.25,'CHES survey bounds',fontsize=12)
#txt.set_path_effects([PathEffects.withStroke(linewidth=2, foreground='w')])

#g.ax_joint.set_ylabel('CHES Economic growth over ecology')
#g.ax_joint.set_xlim((-0.5, 2))
#g.ax_joint.set_ylim((-1, 4))
#g.ax_joint.tick_params(axis = 'x', labelsize = 12)
#g.ax_joint.tick_params(axis = 'y', labelsize = 12)
#g.ax_joint.set_aspect('equal')

plt.tight_layout()

plt.show()

#plt.savefig('Figures/AttitudinalSpace/ARF_lrgen_enviroment_bio_nucleaire.pdf')
#plt.clf()
#plt.close()

# %%
# visualization of three dimensions

xdim = 'latent_dimension_0'
ydim = 'latent_dimension_1'
zdim = 'latent_dimension_2'

ren = {xdim: 'x', ydim: 'y', zdim: 'z'}

f_df = followers_df.rename(columns = ren).drop_duplicates(subset = ['x', 'y', 'z'])
p_df = parliamentarians_df.rename(columns = ren).drop_duplicates(subset = ['x', 'y', 'z'])
df = pd.concat([f_df, p_df], axis = 0)
df = df.drop_duplicates(subset = ['x', 'y', 'z'])
df = df[~df.index.duplicated()]

# %%
# plot first three latent dimensions in 3D

threedimensional_figsize = (6, 5.2)
threedimensional_label_fs = 12
threedimensional_title_fs = 18

fig_df = f_df.sample(n = 10000)  # use a sample of the dataset
    
fig = plt.figure(figsize = threedimensional_figsize)

ax = fig.add_subplot(1, 1, 1, projection = '3d')

ax.scatter(fig_df['x'], fig_df['y'], fig_df['z'], marker = 's', c = fig_df['z'], alpha = 0.5, s = 3)

ax.set_xlabel(r'$\delta^*_1$', fontsize = threedimensional_label_fs)
ax.set_ylabel(r'$\delta^*_2$', fontsize = threedimensional_label_fs)
ax.set_zlabel(r'$\delta^*_3$', fontsize = threedimensional_label_fs)

ax.set_title(country +' in latent space',fontsize=threedimensional_title_fs)

plt.tight_layout()

plt.show()

#plt.savefig('Figures/LatentSpace/%s_latent_3d.png'%country,dpi=300)
#plt.clf()
#plt.close()
